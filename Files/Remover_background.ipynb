# %% [markdown]
# ### **1. Código para instalar módulo do Python que não está disponível no Google Colab.**

# %%
# %pip install rembg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### **2. Código para remover background de imagem**

# %%
from rembg import remove
from PIL import Image
from urllib.request import urlopen

# Imagem
foto = Image.open(urlopen('https://github.com/luizleal1974/Editar-Imagem/raw/main/Files/woman_model.png'))
foto
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=626x417>

# %%
# Remover background
foto_no_bg = remove(foto)
foto_no_bg
# Out:
# ...
# 100%|████████████████████████████████████████| 176M/176M [00:00<00:00, 119GB/s]
# <PIL.Image.Image image mode=RGBA size=626x417>

# %%
# Salvar imagem
foto_no_bg.save('woman_model_no_bg.png')
